# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Prompt a business area that might be worth exploring for a potential agentic AI opportunity."}]

# %%
'''
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
'''
#I choose to use Ollama at least in this lab because I dont wish to spend money on OpenAI API Key. 

#import ollama

#response = ollama.chat(
#    model='llama3.2',
#    messages=messages
#)

#print(response['message']['content'])


#I changed my mind, bought $5 worth of OpenAI API credits.

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# One promising business area worth exploring for a potential agentic AI opportunity is **personalized mental health and wellness support.**
#
# ### Opportunity Overview:
# As mental health awareness grows, there's an increasing demand for accessible, personalized solutions. An agentic AI could provide tailored mental health assistance by adapting to individual user needs, preferences, and emotional states.
#
# ### Key Features:
# 1. **Personalized Interaction:** The AI could learn about users through their interactions, offering customized advice, coping strategies, and exercises tailored to their specific challenges and coping styles.
#
# 2. **Real-time Monitoring:** By integrating with wearable devices or mobile apps, the AI could monitor physiological indicators (like heart rate or sleep patterns) to provide timely interventions or support during potential mental health crises.
#
# 3. **Scalability and Accessibility:** As a virtual assistant, the AI could reach a broader audience, breaking down geographical and economic barriers to mental health resources typically found in traditional therapeutic settings.
#
# 4. **Confidentiality and Anonymity:** The AI could offer a safe space for individuals who may feel uncomfortable seeking help through traditional channels, allowing them to express themselves freely without fear of judgment.
#
# 5. **Integration with Existing Services:** The AI could serve as a complementary tool to existing mental health services, helping to streamline workflows for therapists or psychologists, enabling them to focus on higher-level interventions.
#
# ### Market Potential:
# With the growing prevalence of mental health issues globally and increasing investments in digital health solutions, there is substantial market potential for a service that combines cutting-edge AI technology and a compassionate, user-centered approach to mental wellness.
#
# ### Challenges to Consider:
# - **Ethical considerations:** Building trust while ensuring user data privacy and ethical use of AI in mental health.
# - **Regulatory compliance:** Navigating the legal landscape surrounding mental health services.
# - **Quality assurance:** Ensuring the AI provides evidence-based advice and support to prevent harmful recommendations.
#
# Overall, personalized mental health and wellness support using agentic AI can revolutionize how individuals seek help and manage their mental health, making it a compelling business venture.

# %%
# And now - let's ask for a question:

question = "Present a pain point in the personalized mental health and wellness support industry, something challenging that might be ripe for an Agentic Solution."
messages = [{"role": "user", "content": question}]

# %%
'''
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
'''

from IPython.display import Markdown, display

#response = ollama.chat(
#    model='llama3.2',
#    messages=messages
#)

#question = response['message']['content']

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

question = response.choices[0].message.content
display(Markdown(question))
# Out:
# One significant pain point in the personalized mental health and wellness support industry is the difficulty in accessing and integrating diverse sources of data to create a truly individualized experience for users. Many mental health platforms and applications focus on self-reported data, which can be inconsistent and influenced by various external factors. Additionally, these platforms often lack the capability to seamlessly incorporate other relevant data sources, such as biometric data from wearables, environmental factors, and other health indicators, which could provide a more comprehensive view of an individual's mental health.
#
# This challenge can create barriers for both users and providers. Users may feel that the support they receive is generic and not adequately tailored to their unique situations, leading to decreased engagement and effectiveness of interventions. Providers, on the other hand, may struggle to deliver personalized care due to fragmented data systems and a lack of cohesive insights into the holistic health of their clients.
#
# An Agentic Solution could involve the development of a robust, integrative platform that uses advanced AI and machine learning to analyze diverse data streams, providing mental health and wellness support that is dynamically personalized. This platform could leverage data from user interactions, wearables, social determinants of health, and real-time feedback to deliver tailored interventions and suggestions. By empowering users to have more control over their data and facilitating better communication and integration between various health and wellness resources, the solution could create a more engaging and effective personalized mental health ecosystem.

# %%
# form a new messages list
messages = [{"role": "user", "content": f"Find a solution for the pain point and challenges explained in {question}"}]

#response = ollama.chat(
#    model='llama3.2',
#    messages=messages
#)

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

answer = response.choices[0].message.content

display(Markdown(answer))
# Out:
# **Solution Proposal: Personalized Mental Health Integration Platform (PMHIP)**
#
# ### Overview
# The Personalized Mental Health Integration Platform (PMHIP) would address the pain points associated with delivering integrated and individualized mental health support. By leveraging advanced AI, machine learning, and data integration techniques, PMHIP aims to create a holistic ecosystem where user health and wellness data converge, facilitating tailored intervention strategies that adapt to individual needs.
#
# ### Key Features
#
# 1. **Data Integration Hub**:
#    - **Multi-Source Data Aggregation**: Integrate self-reported data, biometric data from wearables (e.g., heart rate, sleep patterns, activity levels), environmental data (air quality, weather), and social determinants of health (socioeconomic status, community resources).
#    - **API Connectivity**: Establish connections with various health apps, wearables, and electronic health records to pull in relevant user data seamlessly.
#
# 2. **Advanced AI Analytics**:
#    - **Dynamic Personalization**: Utilize machine learning algorithms to analyze aggregated data, identifying patterns and correlations that might influence mental health. This could include recognizing triggers, optimal interventions, or appropriate coping strategies based on real-time data inputs.
#    - **Predictive Modeling**: Develop predictive models that forecast mental health trends based on user data, allowing for proactive support and early intervention.
#
# 3. **User-Centric Interface**:
#    - **Control over Data**: Empower users with tools to manage their data, view personalized insights, and understand how different factors intersect to impact their mental wellness.
#    - **Interactive Feedback System**: Implement real-time feedback mechanisms that allow users to report on their feelings, experiences, and response to interventions, further refining personalization.
#
# 4. **Community and Provider Connectivity**:
#    - **Integrated Care Coordination**: Provide platforms for users to connect with mental health professionals, ensuring that care is aligned with the insights generated from the platform.
#    - **Community Support Features**: Facilitate peer support groups and forums within the app, helping users to find connection and reduce feelings of isolation.
#
# 5. **Tailored Interventions**:
#    - **Personalized Resources and Recommendations**: Deliver tailored resources such as meditation exercises, therapy exercises, educational materials, and coping strategies based on users' unique profiles.
#    - **Adaptive Programming**: Allow intervention strategies to evolve as the user engages with the platform, ensuring that support remains relevant and effective.
#
# ### Implementation Strategy
#
# 1. **Partnerships**: Collaborate with tech companies that provide wearables, electronic health record systems, and wellness apps to facilitate data sharing and interoperability.
#
# 2. **Pilot Program**: Launch a pilot version of the platform in collaboration with select mental health professionals and user groups to refine the usability and efficacy of both data integration and user experience.
#
# 3. **Data Privacy and Security**: Employ robust data protection measures to ensure user privacy and compliance with regulations like HIPAA (Health Insurance Portability and Accountability Act) and GDPR (General Data Protection Regulation).
#
# 4. **Educational Campaign**: Develop a campaign to educate users, providers, and community organizations about the benefits of integrated mental health support and how to utilize PMHIP effectively.
#
# 5. **Continuous Improvement**: Establish a feedback loop with users and providers for ongoing refinement of AI algorithms and user interface features, ensuring the platform remains responsive to evolving needs.
#
# ### Conclusion
#
# The Personalized Mental Health Integration Platform represents a transformative approach to mental health support by addressing the fragmented nature of data currently hindering personalized care. By ensuring comprehensive data integration, advanced analytics, and user-centric design, PMHIP aims to create an engaging, effective, and empowering mental health ecosystem that responds dynamically to individual needs. This innovative solution has the potential to enhance user engagement, improve mental health outcomes, and foster a more connected community of support.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>
